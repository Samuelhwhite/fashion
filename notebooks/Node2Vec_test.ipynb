# %%
import networkx as nx
from node2vec import Node2Vec

# Create a graph

fh=open("clean_store_adjacency.csv", 'r')
graph = nx.read_weighted_edgelist(fh,delimiter=',')


# Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
node2vec = Node2Vec(graph, dimensions=10, walk_length=30, num_walks=200, workers=1)  # Use temp_folder for big graphs
# Out:
# Computing transition probabilities: 100%|██████████| 343/343 [03:20<00:00,  1.71it/s]

# %%
model = node2vec.fit(window=10, min_count=1, batch_words=4)  # Any keywords acceptable by gensim.Word2Vec can be passed, `diemnsions` and `workers` are automatically passed (from the Node2Vec constructor)

# %%
model.wv.save_word2vec_format(r'oof2.emb')

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B2B1-55BA
#
#  Directory of C:\Users\odhra\Documents\GitHub\OSG\fashion\notebooks
#
# 23/03/2020  20:21    <DIR>          .
# 23/03/2020  20:21    <DIR>          ..
# 23/03/2020  19:03    <DIR>          .ipynb_checkpoints
# 23/03/2020  20:20         1,185,981 clean_store_adjacency.csv
# 11/03/2020  14:50            93,534 Clustering.ipynb
# 11/03/2020  14:50            18,604 Exploration_2.ipynb
# 28/02/2020  11:39             3,428 ModelTraining.ipynb
# 23/03/2020  20:21             2,152 Node2Vec_test.ipynb
# 23/03/2020  20:11            73,061 oof.emb
# 11/03/2020  14:26             2,954 PlacesAPI.ipynb
# 22/03/2020  17:32            27,767 product2product_graph_creation.ipynb
# 23/03/2020  18:52        93,523,082 Product2store_graph.csv
# 23/03/2020  19:03            33,498 product2store_graph_creation.ipynb
# 28/02/2020  11:39             3,871 Sales.ipynb
# 11/03/2020  12:49         2,015,728 store_adjacency.csv
# 23/03/2020  19:03             3,333 store_graph_creation.ipynb
#               13 File(s)     96,986,993 bytes
#                3 Dir(s)  113,384,845,312 bytes free

# %%
fh=open("clean_store_adjacency.csv", 'r')
g = nx.read_weighted_edgelist(fh,delimiter=',')

# %%
nx.draw(g)
plt.draw
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d57cef6031ee> in <module>
#       1 nx.draw(g)
# ----> 2 plt.draw
#       3 plt.show()
#
# NameError: name 'plt' is not defined
